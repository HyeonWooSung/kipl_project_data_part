# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
import threading
import schedule
import time

# %%
chrome_options = Options()
chrome_options.add_argument('headless')  # 크롬창 안 띄우고 백그라운드에서 실행

driver = webdriver.Chrome('C:/Users/User/chromedriver.exe',options=chrome_options) # ChromeDriver 설치 경로
basic_url = 'https://comic.naver.com/index'
driver.get('https://comic.naver.com/index')
driver.implicitly_wait(10)
x = 0

print('[전체 인기 순위]')
A_rank = driver.find_elements(By.CSS_SELECTOR,'#container > div.content_wrap > div.Aside__aside_wrap--iF5ju > div:nth-child(2) > ul > li')

for i in A_rank:
    rank = i.find_element(By.CLASS_NAME,'AsideList__ranking--sNPZy').text
    name = i.find_element(By.CLASS_NAME,'ContentTitle__title--e3qXt').text
    print('{}위 : {}'.format(rank,name))

driver.implicitly_wait(10)    

Male = driver.find_element(By.CSS_SELECTOR,'#container > div.content_wrap > div.Aside__aside_wrap--iF5ju > div:nth-child(2) > div > div.ComponentHead__tab_control--R1TyL > button:nth-child(3)')
Male.click()

print("="*20)
print('[남자 인기 순위]')
M_rank = driver.find_elements(By.CSS_SELECTOR,'#container > div.content_wrap > div.Aside__aside_wrap--iF5ju.Aside__type_home_logout--R6qSd > div:nth-child(2) > ul > li')
for i in M_rank:
    rank = i.find_element(By.CLASS_NAME,'AsideList__ranking--sNPZy').text
    name = i.find_element(By.CLASS_NAME,'ContentTitle__title--e3qXt').text
    print('{}위 : {}'.format(rank,name))

driver.implicitly_wait(10)     

Female = driver.find_element(By.CSS_SELECTOR,'#container > div.content_wrap > div.Aside__aside_wrap--iF5ju > div:nth-child(2) > div > div.ComponentHead__tab_control--R1TyL > button:nth-child(2)')
Female.click()

rank_list = []
name_list = []


print("="*20)
print('[여자 인기 순위]')
F_rank = driver.find_elements(By.CSS_SELECTOR,'#container > div.content_wrap > div.Aside__aside_wrap--iF5ju.Aside__type_home_logout--R6qSd > div:nth-child(2) > ul > li')
for i in F_rank:
    rank = i.find_element(By.CLASS_NAME,'AsideList__ranking--sNPZy').text
    name = i.find_element(By.CLASS_NAME,'ContentTitle__title--e3qXt').text
    print('{}위 : {}'.format(rank,name))
    rank_list.append(rank)
    name_list.append(name)
# driver.close() # 브라우저 창 닫기

print(rank_list, name_list)
# Out:
# [전체 인기 순위]
# 1위 : 외모지상주의
# 2위 : 광마회귀
# 3위 : 나 혼자 만렙 뉴비
# 4위 : 역대급 영지 설계사
# 5위 : 화산귀환
# ...
# [남자 인기 순위]
# 1위 : 외모지상주의
# 2위 : 광마회귀
# 3위 : 나 혼자 만렙 뉴비
# 4위 : 역대급 영지 설계사
# 5위 : 화산귀환
# ...
# [여자 인기 순위]
# 1위 : 재혼 황후
# 2위 : 언니, 이번 생엔 내가 왕비야
# 3위 : 문제적 왕자님
# 4위 : 개를 낳았다
# 5위 : 여우놀이
# ['1', '2', '3', '4', '5'] ['재혼 황후', '언니, 이번 생엔 내가 왕비야', '문제적 왕자님', '개를 낳았다', '여우놀이']

# %%
def WebToon_rank():
    chrome_options = Options()
    chrome_options.add_argument('headless')  # 크롬창 안 띄우고 백그라운드에서 실행
    driver = webdriver.Chrome('C:/Users/User/chromedriver.exe',options=chrome_options)
    basic_url = 'https://comic.naver.com/index'
    driver.get('https://comic.naver.com/index')
    driver.implicitly_wait(10)
    x = 0

    print('[전체 인기 순위]')
    A_rank = driver.find_elements(By.CSS_SELECTOR,'#container > div.content_wrap > div.Aside__aside_wrap--iF5ju > div:nth-child(2) > ul > li')

    for i in A_rank:
        rank = i.find_element(By.CLASS_NAME,'AsideList__ranking--sNPZy').text
        name = i.find_element(By.CLASS_NAME,'ContentTitle__title--e3qXt').text
        print('{}위 : {}'.format(rank,name))

    driver.implicitly_wait(10)    

    Male = driver.find_element(By.CSS_SELECTOR,'#container > div.content_wrap > div.Aside__aside_wrap--iF5ju > div:nth-child(2) > div > div.ComponentHead__tab_control--R1TyL > button:nth-child(3)')
    Male.click()

    print("="*20)
    print('[남자 인기 순위]')
    M_rank = driver.find_elements(By.CSS_SELECTOR,'#container > div.content_wrap > div.Aside__aside_wrap--iF5ju.Aside__type_home_logout--R6qSd > div:nth-child(2) > ul > li')
    for i in M_rank:
        rank = i.find_element(By.CLASS_NAME,'AsideList__ranking--sNPZy').text
        name = i.find_element(By.CLASS_NAME,'ContentTitle__title--e3qXt').text
        print('{}위 : {}'.format(rank,name))

    driver.implicitly_wait(10)     

    Female = driver.find_element(By.CSS_SELECTOR,'#container > div.content_wrap > div.Aside__aside_wrap--iF5ju > div:nth-child(2) > div > div.ComponentHead__tab_control--R1TyL > button:nth-child(2)')
    Female.click()

    print("="*20)
    print('[여자 인기 순위]')
    F_rank = driver.find_elements(By.CSS_SELECTOR,'#container > div.content_wrap > div.Aside__aside_wrap--iF5ju.Aside__type_home_logout--R6qSd > div:nth-child(2) > ul > li')
    for i in F_rank:
        rank = i.find_element(By.CLASS_NAME,'AsideList__ranking--sNPZy').text
        name = i.find_element(By.CLASS_NAME,'ContentTitle__title--e3qXt').text
        print('{}위 : {}'.format(rank,name))
    
    rank_list.append(rank)
    name_list.append(name)
    driver.close()
    
    
if __name__=="__main__":
    WebToon_rank()
# Out:
# [전체 인기 순위]
# 1위 : 외모지상주의
# 2위 : 광마회귀
# 3위 : 나 혼자 만렙 뉴비
# 4위 : 역대급 영지 설계사
# 5위 : 화산귀환
# ...
# [남자 인기 순위]
# 1위 : 외모지상주의
# 2위 : 광마회귀
# 3위 : 나 혼자 만렙 뉴비
# 4위 : 역대급 영지 설계사
# 5위 : 화산귀환
# ...
# [여자 인기 순위]
# 1위 : 재혼 황후
# 2위 : 언니, 이번 생엔 내가 왕비야
# 3위 : 문제적 왕자님
# 4위 : 개를 낳았다
# 5위 : 여우놀이

# %%
# schedule.every().day.at("13:30").do(WebToon_rank)

# while True:
#     schedule.run_pending()
#     time.sleep(1)
